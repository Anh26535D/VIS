# %%
import os
from CompaniesmarketcapCrawler import CompaniesmarketcapCrawler
import pandas as pd

# %%
base_path = r"E:\vis\vis_repo\crawl_wrapper\companiesmarketcap"
list_symbols_path = os.path.join(base_path, "list_companies.csv")
save_path = os.path.join(base_path, "dividend")

symbols = pd.read_csv(list_symbols_path).values.flatten(order="F")
symbols = symbols[pd.notna(symbols)]

# %%
CompaniesmarketcapCrawler.getDividendCheckList(symbols, save_path)
# Out:
#      Symbol  Crawl_DividendCash  Crawl_DividendShares  DividendCash  \
# 0     Total                   3                     3             3
# 1       14D                   0                     0             0
# 2      14DN                   0                     0             0
# 3       1AD                   0                     0             0
# 4       1AE                   0                     0             0
# ...     ...                 ...                   ...           ...
# 5055  GMNNB                   0                     0             0
# 5056   BLZO                   0                     0             0
# 5057   AGYO                   0                     0             0
# 5058  LCKOA                   0                     0             0
# 5059    DA1                   0                     0             0
#
#       DividendShares Total
# 0                  3
# 1                  0     0
# 2                  0     0
# 3                  0     0
# ...

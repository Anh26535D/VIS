# %%
from IrbankCrawler import IrbankCrawler

# %%
data = IrbankCrawler("edge").getDataByDocumentCode(document_code="081220230418548831", code="E00012", by="company_code", report_type="pl", useAllColumns=True)

# %%
data
# Out:
# [                      0                         2
#  0                  勘定科目  自 2022年4月1日 至 2023年3月31日
#  1                   売上高                   272,167
#  2                  売上原価                   241,139
#  3                 売上総利益                    31,027
#  4           販売費 及び一般管理費
#  5                   販売費                    15,551
#  6                 一般管理費                     7,370
#  7            販売費・一般管理費計                    22,921
#  8               全事業営業利益                     8,105
#  9                 営業外収益
#  10                 受取利息                         2
#  11                受取配当金                       167
#  12           持分法による投資利益                        21
#  13         営業外収益__受取保険金                       217
#  14                補助金収入                       132
#  15                 為替差益                        40
#  16           営業外収益__その他                       219
#  17               営業外収益計                       801
#  18                営業外費用
# ...
